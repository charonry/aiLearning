# %%
import os

# 打印当前工作目录（相对路径的基准！）
print("代码执行的基准路径（工作目录）：", os.getcwd())
# 打印当前ipynb文件的实际存储路径（对比用）
print("ipynb文件自身的路径：", os.path.abspath(__file__) if '__file__' in locals() else os.path.abspath("scikit_learn"))
